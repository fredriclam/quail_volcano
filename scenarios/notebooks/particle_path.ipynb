# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 10, 20)
t = np.linspace(0, 1, 33)
mg_t, mg_x = np.meshgrid(t, x)
test_u = mg_x
plt.contourf(mg_t, mg_x, test_u)
plt.streamplot(mg_t, mg_x, np.ones_like(test_u), test_u, density=1)
